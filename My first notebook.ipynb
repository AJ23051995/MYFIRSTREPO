# %%
print("Hello world")
# Out:
# Hello world

# %%
 print("Hii guys! My name is Akash ")
# Out:
# Hii guys! My name is Akash

# %%
print('my name is akash')
# Out:
# my name is akash

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
print("hello")
# Out:
# hello

# %%
x=20
y=5
print(x)
# Out:
# 20

# %%
print(x)
# Out:
# 20

# %%
print(x+y)
# Out:
# 25

# %%
z=x*y
print(z)
# Out:
# 100

# %%
print("sum of x & y =",x+y)
# Out:
# sum of x & y = 25

# %%
print("The values of x & y are",x,"&",y,"respectively.")
# Out:
# The values of x & y are 20 & 5 respectively.

# %%
print("The multiplication of x and y equals to",x*y,"respectively.")
# Out:
# The multiplication of x and y equals to 100 respectively.

# %%
print("multiply of x & y =",x*y)
# Out:
# multiply of x & y = 100

# %%
x=4
y=10
print("division of x & y =",x/y)
# Out:
# division of x & y = 0.4

# %%
x=10
y=10
print("the values of x & y =",x,"&",y)
# Out:
# the values of x & y = 10 & 10
